# %%
import pandas as pd

# %%
df=pd.read_csv("/content/drive/MyDrive/ssss.csv")

# %%
df
# Out:
#    Order_id  product     category  quantity    ppu region
# 0      1001   Laptop  electronics         2  60000  north
# 1      1002    phone  electronics         1  25000  south
# 2      1003    chair    furniture         4   3000  north
# 3      1004       nb   stationery        10     50   east
# 4      1005     desk    furniture         2   7000   west
# 5      1006      pen   stationery        20     10   east
# 6      1007  monitor  electronics         1  12000  south
# 7      1008    chair    furniture         1   3000   west

# %%
df['Total']=df['quantity']*df['ppu']

# %%
df
# Out:
#    Order_id  product     category  quantity    ppu region   Total
# 0      1001   Laptop  electronics         2  60000  north  120000
# 1      1002    phone  electronics         1  25000  south   25000
# 2      1003    chair    furniture         4   3000  north   12000
# 3      1004       nb   stationery        10     50   east     500
# 4      1005     desk    furniture         2   7000   west   14000
# 5      1006      pen   stationery        20     10   east     200
# 6      1007  monitor  electronics         1  12000  south   12000
# 7      1008    chair    furniture         1   3000   west    3000

# %%
df.loc[df.category=='furniture']
# Out:
#    Order_id product   category  quantity   ppu region  Total
# 2      1003   chair  furniture         4  3000  north  12000
# 4      1005    desk  furniture         2  7000   west  14000
# 7      1008   chair  furniture         1  3000   west   3000

# %%
dff=df.sort_values(by='Total',ascending=False)
dff.head(3)
# Out:
#    Order_id product     category  quantity    ppu region   Total
# 0      1001  Laptop  electronics         2  60000  north  120000
# 1      1002   phone  electronics         1  25000  south   25000
# 4      1005    desk    furniture         2   7000   west   14000

# %%
df.Total.describe()
# Out:
# count         8.000000
# mean      23337.500000
# std       39930.616163
# min         200.000000
# 25%        2375.000000
# 50%       12000.000000
# 75%       16750.000000
# max      120000.000000
# Name: Total, dtype: float64

# %%
df.quantity.mean()
# Out:
# np.float64(5.125)

# %%
df.groupby('region')['quantity'].mean()
# Out:
# region
# east     15.0
# north     3.0
# south     1.0
# west      1.5
# Name: quantity, dtype: float64
